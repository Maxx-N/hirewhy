# %%
from scraper import fetch_website_contents

import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

from user_input import ask_choice
from prompter import get_messages

# %%
load_dotenv()

openrouter_api_key = os.getenv("OPENROUTER_API_KEY")
openrouter_base_url = os.getenv("OPENROUTER_BASE_URL")

openrouter_client = OpenAI(api_key=openrouter_api_key, base_url=openrouter_base_url)

MODEL = "openai/gpt-6-luna"

# %%
question = "What language would you like the professional career coach to speak?"
options = ["English", "Spanish", "Italian", "German", "French"]
language = ask_choice(question, options)

profile_url = input("Enter your LinkedIn profile URL:")
experience_url = f"{profile_url}/details/experience/"

job_description_url = input("Enter the LinkedIn URL for the job description:")

try:
    profile_contents = fetch_website_contents(profile_url)
    experience_contents = fetch_website_contents(experience_url)
    job_contents = fetch_website_contents(job_description_url)
except Exception as e:
    print(f"An error occurred while fetching website contents: {e}")

messages = get_messages(language, profile_contents, experience_contents, job_contents)

response = openrouter_client.chat.completions.create(model=MODEL, messages=messages)

compelling_case = response.choices[0].message.content
# Out:
# What language would you like the professional career coach to speak?
#   1. English
#   2. Spanish
#   3. Italian
#   4. German
#   5. French

# %%
display(Markdown(compelling_case))
# Out:
# ## Le positionnement le plus convaincant
#
# Maxime présente une forte adéquation avec le **cœur technique et le mode de travail** recherchés par lemlist : construire des systèmes agentiques utiles, les intégrer dans un produit logiciel et garder le problème métier au centre. Son parcours associe plus de huit ans de développement full stack, une spécialisation pratique en IA appliquée et une expérience de fondateur et de formateur technique.
#
# La réserve à traiter franchement est l’ancienneté : l’annonce demande **10 ans ou plus**, tandis que le profil indique **8+ ans**. En outre, les éléments fournis ne documentent pas de résultats chiffrés en production ni une responsabilité explicite sur l’évaluation et les garde-fous. Il serait donc peu crédible d’affirmer que chaque critère est déjà démontré. La meilleure candidature consiste à prouver une adéquation très forte aux enjeux du poste, tout en reconnaissant précisément ces points à valider.
#
# ## Argumentaire de candidature
#
# > **Ce qui m’attire chez lemlist, c’est l’ambition de faire évoluer un logiciel de vente d’un outil que l’on pilote vers un système agentique qui produit réellement des résultats pour l’utilisateur. C’est précisément à cette jonction — entre capacités des LLM, ingénierie logicielle et valeur métier — que je veux contribuer.**
# >
# > **J’apporte plus de huit ans d’expérience en développement logiciel full stack**, notamment avec React, Node.js et Python, ainsi qu’une spécialisation en IA appliquée. Cette double compétence est particulièrement pertinente pour un rôle où il ne suffit pas de faire fonctionner un agent en démonstration : il faut transformer ses capacités en fonctionnalités utilisables dans un produit, en collaboration avec les équipes d’ingénierie et de produit.
# >
# > **J’ai travaillé concrètement sur les briques centrales de votre projet** : orchestration d’agents, appels d’outils, RAG et recherche vectorielle, structuration des réponses, usage des API OpenAI, Anthropic et Gemini, ainsi que fine-tuning avec QLoRA. Mes projets, comme City Traveler et Scrapitchat, illustrent cette démarche : décomposer une tâche, laisser le modèle décider quels outils appeler, exploiter des sources non structurées et restituer une réponse structurée dans une interface logicielle.
# >
# > **Ma façon d’aborder l’IA est orientée problème utilisateur, pas démonstration technologique.** Je pars d’un besoin, j’expérimente, puis je construis une solution logicielle autour du modèle. Mon parcours de fondateur renforce cette approche entrepreneuriale : prendre des initiatives, avancer malgré l’incertitude et assumer la réalisation d’un produit. Et mon expérience de formateur technique — notamment auprès d’équipes chez Sopra Steria et Sogeti — me permet aussi de travailler avec des interlocuteurs variés et de faciliter l’adoption de nouvelles pratiques.
# >
# > **Je peux ainsi contribuer à lemlist avec une combinaison utile de compétences :** une base solide en ingénierie logicielle, une pratique actuelle des systèmes agentiques et une attention constante à leur utilité concrète pour les utilisateurs. Je souhaite mettre cette combinaison au service de vos enjeux d’orchestration, de contexte et de retrieval, tout en renforçant la fiabilité des fonctionnalités livrées.
#
# ## Pourquoi l’adéquation est crédible
#
# - **Ingénierie logicielle appliquée :** huit ans et plus de développement full stack apportent une base pertinente pour intégrer l’IA dans un produit, plutôt que de s’en tenir au prototypage de modèles.
# - **Agents et orchestration :** le profil et les projets décrivent des boucles agentiques, des outils appelés par le modèle et des sous-agents — des sujets au centre du quotidien annoncé par lemlist.
# - **Contexte et retrieval :** l’expérience déclarée en RAG, recherche vectorielle et traitement de sources non structurées recoupe directement les besoins de context engineering et de retrieval.
# - **Approche produit et utilisateur :** Maxime insiste sur le fait de partir du problème métier, et ses projets relient des composants IA à des usages identifiables plutôt qu’à une simple expérimentation technique.
# - **Esprit d’initiative et collaboration :** son profil de fondateur et son expérience de formateur soutiennent les qualités de proactivité, de responsabilité et de transmission recherchées dans un environnement rapide.
#
# ## Les points à sécuriser en entretien
#
# 1. **Les dix ans d’expérience demandés :** répondre exactement sur la durée, sans arrondir les huit ans et plus à dix. Il peut expliquer que son expérience directement pertinente en ingénierie logicielle est déjà conséquente, et mettre en avant son niveau de responsabilité ainsi que la continuité entre logiciel et IA appliquée.
# 2. **La production à l’échelle :** préparer un exemple précis démontrant ce qui a été effectivement déployé, pour quels utilisateurs, avec quelles contraintes et quels résultats. Les projets visibles dans le profil ne suffisent pas, à eux seuls, à prouver une exploitation à grande échelle.
# 3. **Évaluation et garde-fous :** détailler les pratiques réellement maîtrisées — jeux de tests, critères de qualité, gestion des erreurs, sécurité, monitoring — et distinguer clairement l’expérience acquise de ce qu’il souhaite approfondir chez lemlist.
# 4. **Arbitrages coût, latence et qualité :** préparer un cas concret où il a comparé des modèles ou des approches et expliquer les critères de décision.
#
# **En bref :** Maxime est très bien aligné avec la substance du poste — logiciel, agents, retrieval et sens du produit. Sa candidature sera la plus convaincante si elle présente cette adéquation sans masquer l’écart sur les années d’expérience ni attribuer à ses projets des preuves de production qui ne figurent pas dans les éléments disponibles.
