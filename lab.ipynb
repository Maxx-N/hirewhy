# %%
from scraper import fetch_website_contents

import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

from user_input import ask_choice
from prompter import get_messages

# %%
load_dotenv()

openrouter_api_key = os.getenv("OPENROUTER_API_KEY")
openrouter_base_url = os.getenv("OPENROUTER_BASE_URL")

openrouter_client = OpenAI(api_key=openrouter_api_key, base_url=openrouter_base_url)

MODEL = "openai/gpt-6-luna"

# %%
def create_compelling_case():
    question = "What language would you like the professional career coach to speak?"
    options = ["English", "Spanish", "Italian", "German", "French"]
    language = ask_choice(question, options)

    profile_url = input("Enter your LinkedIn profile URL:")
    experience_url = f"{profile_url}/details/experience/"

    job_description_url = input("Enter the LinkedIn URL for the job description:")

    try:
        profile_contents = fetch_website_contents(profile_url)
        experience_contents = fetch_website_contents(experience_url)
        job_contents = fetch_website_contents(job_description_url)
    except Exception as e:
        print(f"An error occurred while fetching website contents: {e}")

    messages = get_messages(
        language, profile_contents, experience_contents, job_contents
    )

    response = openrouter_client.chat.completions.create(model=MODEL, messages=messages)

    return display(Markdown(response.choices[0].message.content))

# %%
def stream_compelling_case():
    question = "What language would you like the professional career coach to speak?"
    options = ["English", "Spanish", "Italian", "German", "French"]
    language = ask_choice(question, options)

    profile_url = input("Enter your LinkedIn profile URL:")
    experience_url = f"{profile_url}/details/experience/"

    job_description_url = input("Enter the LinkedIn URL for the job description:")

    try:
        profile_contents = fetch_website_contents(profile_url)
        experience_contents = fetch_website_contents(experience_url)
        job_contents = fetch_website_contents(job_description_url)
    except Exception as e:
        print(f"An error occurred while fetching website contents: {e}")

    messages = get_messages(
        language=language,
        profile_contents=profile_contents,
        experience_contents=experience_contents,
        job_contents=job_contents,
    )

    stream = openrouter_client.chat.completions.create(
        model=MODEL, messages=messages, stream=True
    )
    response = ""
    handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        if not chunk.choices[0].delta:
            continue
        response += chunk.choices[0].delta.content or ""
        handle.update(Markdown(response))

# %%
stream_compelling_case()
# Out:
# What language would you like the professional career coach to speak?
#   1. English
#   2. Spanish
#   3. Italian
#   4. German
#   5. French
# ## Why Maxime is a strong fit for Bonne Idée IA
#
# Bonne Idée IA is looking for more than an engineer who can implement a defined feature. It needs someone who can understand an open-ended problem, choose a practical approach, build and test a solution, and help turn promising prototypes into usable products. Maxime’s profile is unusually well aligned with that combination.
#
# **He brings the generalist engineering foundation the role calls for.** Maxime has more than eight years of full-stack software experience, with React, Node.js, and Python in his toolkit. That background matters because the job spans AI, backend, frontend, APIs, and product development—not just model experimentation. He can approach AI as part of a complete software solution rather than as a standalone demo.
#
# **His recent work directly reflects Bonne Idée IA’s AI focus.** Maxime describes hands-on experience with LLM APIs, RAG, vector search, fine-tuning, and tool-using agents. His projects make that experience concrete: *City Traveler* uses an agentic workflow, tools generated from Python functions, specialized sub-agents, structured JSON outputs, and text-to-speech. *Scrapitchat* combines browser-based web scraping, LLM-selected pages, and interchangeable GPT, Claude, and local Llama models. These are relevant examples of evaluating AI capabilities and assembling them into working applications.
#
# **He has a practical, iterative product mindset.** The role calls for someone comfortable moving between a quick proof of concept and a product that people can actually use. Maxime’s projects show a willingness to build, experiment, and refine rather than stay at the level of ideas. His profile also describes him as a founder, and he has shared an app, eBooKids, as available on iOS and Android—evidence of product-building beyond isolated technical exercises. His own stated approach is to start with the business problem, experiment, and focus on delivering value.
#
# **He appears well suited to a small, autonomous team.** Bonne Idée IA explicitly values initiative, adaptability, and the ability to make progress without a highly prescriptive specification. Maxime’s profile presents a builder who learns new technologies by applying them to projects, and his technical training work with organizations including Sopra Steria and Sogeti suggests he can also explain technical concepts and support others’ adoption. That combination—hands-on engineering and teaching—is a useful foundation for becoming a technical reference as the team grows.
#
# **The future Lead Tech path is credible, with room to grow.** Maxime’s eight-plus years in software, founder experience, broad full-stack perspective, and training background create a strong basis for taking on increasing technical responsibility. His profile does not establish prior formal team leadership, so the strongest case is not that he has already held the Lead Tech role; it is that he has several of the foundations Bonne Idée IA wants to develop toward it.
#
# ### Application-ready pitch
#
# > I’m a full-stack software engineer with more than eight years of experience building software, and I now focus on applied AI: LLM applications, RAG, vector search, fine-tuning, and agentic systems. What attracts me to Bonne Idée IA is the opportunity to work across the full problem-solving cycle—from understanding a business need and testing an approach to building a product that can be used in practice.
# >
# > My recent projects reflect that approach. I built an agentic application that turns information about a city into a structured, localized, spoken briefing, using tools, specialized sub-agents, and structured outputs. I also built a website-based conversational application combining browser automation, page selection by an LLM, and support for different model providers. These projects have given me hands-on experience translating modern AI capabilities into functioning software, while keeping the user-facing product in view.
# >
# > I also bring a broader software engineering perspective. My background includes React, Node.js, and Python, so I am comfortable working across the application rather than treating the AI component in isolation. As a founder and technical trainer, I have also had to think about value, usability, and how people adopt technology—not only whether the code works.
# >
# > I would bring Bonne Idée IA a pragmatic, curious, and autonomous approach: prototype quickly when the question is still open, evaluate alternatives, and then invest in reliability and maintainability as a solution moves toward production. I would welcome the opportunity to contribute to your current products, help build reusable technical foundations, and grow into greater architectural and team responsibilities as the company develops.
#
# **Points to substantiate in an application or interview:** the supplied profile does not show Maxime’s Experience section or confirm the Master’s requirement, and it does not provide detailed evidence of production-scale deployment, OCR/vision work, CI/CD, monitoring, or formal leadership. He should address these directly with his résumé, project details, and examples rather than imply experience that is not established here.
